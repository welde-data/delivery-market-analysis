# %% [markdown]
# # changing into csv

# %%
import pandas as pd
from pathlib import Path

out_dir = Path(r"C:\Users\welde\Desktop\delivery-market-analysis\delivery-market-analysis\data\exports")
out_dir.mkdir(parents=True, exist_ok=True)

tables = ["restaurants", "menuItems", "categories", "categories_restaurants",
          "locations", "locations_to_restaurants", "sqlite_sequence"]

for t in tables:
    df = pd.read_sql_query(f'SELECT * FROM "{t}";', con)
    df.to_csv(out_dir / f"{t}.csv", index=False)

out_dir
